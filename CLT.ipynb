# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.distributions.empirical_distribution import ECDF
from scipy.stats import norm

# %%
df = pd.read_csv('weight-height.csv')
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
sns.displot(df['Height'])
plt.show()

# %%
sigma = df['Height'].std()
sigma
# Out:
# 3.8475281207732293

# %%
mu = df['Height'].mean()
mu
# Out:
# 66.36755975482124

# %%
df['Height'].sample(10).mean()
# Out:
# 65.78931648469097

# %%
sample_5 = [df['Height'].sample(5).mean() for i in range(10000)]
sample_5
# Out:
# [68.60084131331769,
#  65.29272959757658,
#  65.89563544167166,
#  67.82948988693063,
#  67.03901095746576,
#  67.12085040139624,
#  66.9215625887184,
#  66.65253511714636,
#  67.7713737740415,
#  70.48851642415787,
#  66.63180848466172,
#  65.23654565466987,
#  65.39539085714343,
#  66.561241568237,
#  67.2268432180202,
#  66.3174421058377,
#  64.34434427625563,
#  68.57380792080677,
#  67.00285452535982,
#  66.14938964934518,
#  68.17474999428835,
#  65.7472089020519,
#  68.17356715940716,
#  70.47824702482782,
#  63.871432171838045,
#  65.16415391790798,
#  64.50757842944407,
#  66.24883918004335,
#  64.11332339976995,
#  65.97013755579628,
#  66.27357487214628,
#  66.09257043891606,
#  67.29204753227052,
#  64.15144057838563,
#  64.53093161003332,
#  63.59630571072686,
#  66.80729251449696,
#  66.66333852554024,
#  67.94294891350783,
#  64.79394902486148,
#  67.64084413579846,
#  67.53402470274534,
#  66.7578561690289,
#  67.20832524619345,
#  68.40830528172519,
# ...

# %%
sns.displot(sample_5)
plt.show()

# %%
sample_20 = [df['Height'].sample(20).mean() for i in range(10000)]

# %%
sns.displot(sample_20)
plt.show()

# %% [markdown]
# Systolic blood pressure of a group of people is known to have an average of 122 mmHg and a standard deviation of 10 mmHg Calculate the probability that the average blood pressure of 16 people will be greater than 125 mmHg.

# %%
1 - norm.cdf(1.2)
# Out:
# 0.11506967022170822

# %%
1 - norm.cdf(x=125,loc=122,scale=2.5)
# Out:
# 0.11506967022170822

# %% [markdown]
# Weekly toothpaste sales have a mean 1000 and std dev 200. What is the probability that the average weekly sales next month is more than 1110?

# %%
1-norm.cdf(110/100)
# Out:
# 0.13566606094638267

# %%
1 - norm.cdf(x=1110,loc=1000,scale=100)
# Out:
# 0.13566606094638267

# %% [markdown]
# In an ecommerce website, the average purchase amount per bill is $80 with a standard deviation of $15. If we randomly select a sample of 50 customers, what is the probabiltity that the average purchase amount in the sample will be less than $75

# %%
norm.cdf((75-80)/(15/np.sqrt(50)))
# Out:
# 0.0092110627270495

# %%
norm.cdf(x=75,loc=80,scale=(15/np.sqrt(50)))
# Out:
# 0.0092110627270495
