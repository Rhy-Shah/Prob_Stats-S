# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(data=df[df["sex"]=="male"],
            y = "age",
            x = "alive")
plt.show()

# %%
sns.boxplot(data=df[df["sex"]=="female"],
            y = "age",
            x = "alive")
plt.show()

# %%
sns.barplot(data=df[df["sex"]=="male"],
            y = "age",
            x = "alive")
plt.show()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_second = df.loc[df['class']=='Second']
df_second['fare']
# Out:
# 9      30.0708
# 15     16.0000
# 17     13.0000
# 20     26.0000
# 21     13.0000
#         ...
# 866    13.8583
# 874    24.0000
# 880    26.0000
# 883    10.5000
# 886    13.0000
# Name: fare, Length: 184, dtype: float64

# %%
sns.histplot(df_second['fare'])
plt.show()

# %%
df_second.loc[df_second['fare']>=60]['survived'].mean()
# Out:
# 0.2857142857142857

# %%
df_second['survived'].mean()
# Out:
# 0.47282608695652173

# %%
df.loc[df['class']=='Third']['fare'].mean()
# Out:
# 13.675550101832993

# %%
df.loc[df['class']=='Third']['fare'].median()
# Out:
# 8.05

# %%
df_second.loc[df_second['fare']>=60]['survived'].mean()
# Out:
# 0.2857142857142857

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# age_b = df[(df['age']>=20) & (df['age']<=40)]

# %%
df[(df['survived']==1) & (df['sex']=='male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df[(df['survived']==1) & (df['sex']=='female')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
labels = ['0-19','20-39', '40-59', '60-79']
bins = [0,20, 40, 60, 80]

df['age_bins'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
df['age_bins'].value_counts()
# Out:
# 20-39    385
# 0-19     179
# 40-59    128
# 60-79     22
# Name: age_bins, dtype: int64

# %%
df[df['sex']=='female']['age_bins'].value_counts()
# Out:
# 20-39    136
# 0-19      77
# 40-59     45
# 60-79      3
# Name: age_bins, dtype: int64

# %%
df_alone = df.loc[df['alone']==True]
df_not_alone = df.loc[df['alone']==False]

# %%
df_alone[df_alone['survived']==True]['age'].median()
# Out:
# 30.0

# %%
df[df['survived']==False]['age'].median()
# Out:
# 28.0

# %%
df_alone[df_alone['survived']==False]['age'].median()
# Out:
# 29.0

# %%
df[df['survived']==True]['age'].median()
# Out:
# 28.0

# %%
df[(df['alone']==False) & df['survived']==False]['age'].median()
# Out:
# 29.0

# %%
df[df['survived']==False]['age'].median()
# Out:
# 28.0

# %%
df[(df['alone']==False) & df['survived']==True]['age'].median()
# Out:
# 24.0

# %%
sns.boxplot(x='alone',y='age',data=df,hue='survived')
plt.show()

# %%
import math

# %%
(math.factorial(10)*math.factorial(10)*2)/math.factorial(20)
# Out:
# 1.082508822446903e-05
